# %% [markdown]
# # Import Libraries

# %%
# importing libraries
import datetime
import pandas as pd
import numpy as np
import plotly.graph_objects as go
import plotly.offline as pyo
import plotly.express as px
import collections
import pycountry
import difflib
import seaborn as sns
import matplotlib.pyplot as plt
from plotly.subplots import make_subplots
from wordcloud import WordCloud
from IPython.core.display import HTML
# must be installed manually
# conda install -c conda-forge pycountry
# conda install -c conda-forge wordcloud
# statsmodels needs to be installed, used for trandlines

# %% [markdown]
# # Global variables and settings

# %% [markdown]
# ### Align matplotlib graphs in the center

# %%
# used to center matplotlib graphs
HTML("""
<style>
.output_png {
    display: table-cell;
    text-align: center;
    vertical-align: middle;
}
</style>
""")
# Out:
# <style>
# .output_png {
#     display: table-cell;
#     text-align: center;
#     vertical-align: middle;
# }
# </style>

# %% [markdown]
# ### Bold character

# %%
BOLD_BEGIN = '\033[1m'
BOLD_END = '\033[0m'

# %% [markdown]
# # Read CSV files

# %%
# Suicides dataset: https://www.kaggle.com/russellyates88/suicide-rates-overview-1985-to-2016
# used to get suicides data
datset1_url = "https://stojkovski.ch/master.csv"
# Continent dataset: https://pkgstore.datahub.io/JohnSnowLabs/country-and-continent-codes-list/country-and-continent-codes-list-csv_csv/data/b7876b7f496677669644f3d1069d3121/country-and-continent-codes-list-csv_csv.csv
# used to get country continents
datset2_url = "https://stojkovski.ch/country_codes.csv"
# UV Ratiation in 2014 dataset: https://apps.who.int/gho/data/view.main.35300
# used to get UV Radiation in 2014
datset3_url = "https://stojkovski.ch/UV_1.csv"
# read the dataset and store it into a pandas dataframe
df = pd.read_csv(datset1_url)
df2 = pd.read_csv(datset2_url)
df3 = pd.read_csv(datset3_url)

# %% [markdown]
# # Understanding the datasets

# %%
# %%capture

df.head()
df.info()
df.duplicated().sum()
df.nunique()
df.describe()
df.dtypes
df.shape

# %%
# %%capture

df2.head()
df2.info()
df2.duplicated().sum()
df2.nunique()
df2.describe()
df2.dtypes
df2.shape

# %%
# %%capture

df3.head()
df3.info()
df3.duplicated().sum()
df3.nunique()
df3.describe()
df3.dtypes
df3.shape

# %% [markdown]
# # Data Wrangling

# %% [markdown]
# ### Remove incomplete years

# %%
# the following years need to be removed beacuse the data contained is incomplete or not accurate
years_to_be_removed = [2016]
df = df.drop(df[df['year'].isin(years_to_be_removed)].index)

# %% [markdown]
# ### Rename wrong countries in order to be compliant with ISO 3166

# %%
# Change wrong country names according to ISO 3166
df.loc[df['country'] == 'Czech Republic', 'country'] = 'Czechia'
df.loc[df['country'] == 'Republic of Korea', 'country'] = 'Korea, Republic of'
df.loc[df['country'] == 'Macau', 'country'] = 'Macao'

# %% [markdown]
# ### Rename columns containing special characters

# %%
# Rename columns containing special characters
df.rename(columns = {'suicides/100k pop': 'suicides_100k_pop'}, inplace=True)
df.rename(columns = {'country-year': 'country_year'}, inplace=True)
df.rename(columns = {'HDI for year': 'hdi_for_year'}, inplace=True)
df.rename(columns = {' gdp_for_year ($) ': 'gdp_for_year'}, inplace=True)
df.rename(columns = {'gdp_per_capita ($)': 'gdp_per_capita'}, inplace=True)

# %% [markdown]
# ### Change wrong data types

# %%
# Fix gdp_for_year not recognizes as integer
df['gdp_for_year'] = df['gdp_for_year'].astype('str')
df['gdp_for_year'] = df['gdp_for_year'].str.replace(',', '')
df['gdp_for_year'] = pd.to_numeric(df['gdp_for_year'], errors='coerce')

# %% [markdown]
# ### Add country code column

# %%
iso_country_names = [x.name for x in pycountry.countries] 
country_isocountry_best_match=dict()
acceptance_confidence=0.8

# country -> isocountry mapping
for country in set(df['country']):
    best_confidence=0
    matching_countries = difflib.get_close_matches(country, iso_country_names)
    for match in matching_countries:
        confidence = difflib.SequenceMatcher(None, match, country).ratio()
        if (confidence > acceptance_confidence and confidence>best_confidence):
            best_confidence=confidence
            country_isocountry_best_match[country]  = match
    if (matching_countries is None):
         country_isocountry_best_match[country]  = 'Unknown'

# country -> isocountrycode mapping
country_isocountrycode=dict()
for notiso_country in country_isocountry_best_match.keys():
    iso_country = country_isocountry_best_match.get(notiso_country) 
    iso_countrycode = pycountry.countries.get(name=iso_country).alpha_3
    country_isocountrycode[notiso_country]=iso_countrycode

# write resul minto main dataset
for country in set(df['country']):
    countrycode = country_isocountrycode.get(country)
    df.loc[df['country']==country, 'country_code'] = countrycode

# %% [markdown]
# ### Add continent colum

# %%
# Add continent
for country in set(df['country']):
    cc = df.loc[df['country']==country,'country_code'].iloc[0]
    continent = df2[df2['Three_Letter_Country_Code'] == cc]['Continent_Name'].iloc[0]
    df.loc[df['country']==country, 'continent'] = continent

# %% [markdown]
# ### Add hdi_category column

# %%
for hdi in df['hdi_for_year'].unique():
    if hdi <= 0.549:
        hdi_category = 'low'
    elif hdi > 0.549 and hdi <= 0.699:
        hdi_category = 'medium'
    elif hdi > 0.699 and hdi <= 0.799:
        hdi_category = 'high'
    elif hdi > 0.799 and hdi <= 1:
        hdi_category = 'very high'
    else:
        hdi_category = 'unknown'
    df.loc[df['hdi_for_year']==hdi, 'hdi_category'] = hdi_category
df.fillna({'hdi_category':'unknown'}, inplace=True)

# %%
# suicides_no and population for each year
# suicides_and_population_per_year = df.groupby("year")[['suicides_no','population']].sum()
# year_suicidesno_relation =  suicides_and_population_per_year["suicides_no"] / suicides_and_population_per_year["population"] * 100000
year_suicidesno_relation = df.groupby(['year'])['suicides_100k_pop'].mean().reset_index()

# anootation_df = year_suicidesno_relation.reset_index(name='suicides')
max_suicides_count = year_suicidesno_relation.max()['suicides_100k_pop']
max_suicides_year = year_suicidesno_relation.loc[year_suicidesno_relation['suicides_100k_pop']==max_suicides_count]['year'].iloc[0]
suicides_mean = year_suicidesno_relation.mean()

only_swiss = df[df['country'] == 'Switzerland']
only_swiss = only_swiss.groupby("year")['suicides_100k_pop'].mean().reset_index()

# %%
fig = go.Figure()
fig.add_trace(
    go.Scatter(
        x=year_suicidesno_relation['year'],
        y=year_suicidesno_relation['suicides_100k_pop'],
        mode='lines+markers',
        name='lines'
    )
)

# Horizontal Line (mean of suicides)
#fig.add_shape(
#        dict(
#            type="line",
#            x0=suicides_and_population_per_year.index.min(),
#            y0=suicides_mean,
#            x1=suicides_and_population_per_year.index.max(),
#            y1=suicides_mean,
#            line=dict(
#                color="MediumPurple",
#                width=4,
#                dash="dot",
#            )
#))

fig.update_layout(
    title=dict(
        text='Global suicides (per 100k people)',
        y=0.9,
        x=0.5,
        xanchor='center',
        yanchor='top'
    ),
    xaxis=dict(
        title='Year',
        linecolor='rgb(204, 204, 204)',
    ),
    yaxis=dict(
        title='Suicides (per 100k people)',
    ),
    annotations=[
        dict(
            arrowsize=2,
            arrowwidth=1,
            x=1985,
            y=year_suicidesno_relation.query('year == "1985"')['suicides_100k_pop'].iloc[0],
            xref="x",
            yref="y",
            text=f"year: 1985<br>count: {round(11.826,1)}",
            showarrow=True,
            arrowhead=1,
            ax=0,
            ay=-40
        ),
        dict(
            arrowsize=2,
            arrowwidth=1,
            x=max_suicides_year,
            y=max_suicides_count,
            xref="x",
            yref="y",
            text=f"year: {max_suicides_year}<br>count: {round(max_suicides_count,1)}",
            showarrow=True,
            arrowhead=1,
            ax=0,
            ay=-40
        ),
        dict(
            arrowsize=2,
            arrowwidth=1,
            x=2015,
            y=year_suicidesno_relation.query('year == "2015"')['suicides_100k_pop'].iloc[0],
            xref="x",
            yref="y",
            text=f"year: 2015<br>count: {round(13.786,1)}",
            showarrow=True,
            arrowhead=1,
            ax=0,
            ay=-40
        ),
    ]
)

fig.show()
# Out:
# <div>
#
#
#             <div id="ca6000e1-7e9d-44cc-adf5-3229e6bd9e4b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ca6000e1-7e9d-44cc-adf5-3229e6bd9e4b")) {
#                     Plotly.newPlot(
#                         'ca6000e1-7e9d-44cc-adf5-3229e6bd9e4b',
# ...

# %%
continent_df = df.groupby(['year','continent'])['suicides_100k_pop'].mean().reset_index()
africa_df = continent_df[continent_df['continent']=='Africa']
asia_df = continent_df[continent_df['continent']=='Asia']
europe_df = continent_df[continent_df['continent']=='Europe']
namerica_df = continent_df[continent_df['continent']=='North America']
oceania_df = continent_df[continent_df['continent']=='Oceania']
samerica_df = continent_df[continent_df['continent']=='South America']

# %%
fig = make_subplots(
    rows=3,
    cols=2,
    subplot_titles=("Europe", "Asia", "Africa", "Oceania", "North America", "South America"),
    shared_xaxes=True,
    x_title="Year",
    y_title="Suicides (per 100k people)",
    vertical_spacing = 0.10,
)

fig.append_trace(go.Scatter(
    name="Europe",
    x=europe_df['year'],
    y=europe_df['suicides_100k_pop'],
), row=1, col=1)

fig.append_trace(go.Scatter(
    name="Asia",
    x=asia_df['year'],
    y=asia_df['suicides_100k_pop'],
), row=1, col=2)

fig.append_trace(go.Scatter(
    name="Africa",
    x=africa_df['year'],
    y=africa_df['suicides_100k_pop'],
), row=2, col=1)

fig.append_trace(go.Scatter(
    name="Oceania",
    x=oceania_df['year'],
    y=oceania_df['suicides_100k_pop'],
), row=2, col=2)

fig.append_trace(go.Scatter(
    name="North America",
    x=namerica_df['year'],
    y=namerica_df['suicides_100k_pop'],
), row=3, col=1)

fig.append_trace(go.Scatter(
    name="South America",
    x=samerica_df['year'],
    y=samerica_df['suicides_100k_pop'],
), row=3, col=2)


fig.update_layout(
    height=600,
    width=900,
    title=dict(
        text='Trends over time by Continent (per 100k people)',
        y=0.95,
        x=0.5,
        xanchor='center',
        yanchor='top'
    ),
    showlegend=False,
)

max_suicides=5+max([europe_df['suicides_100k_pop'].max(), asia_df['suicides_100k_pop'].max(), africa_df['suicides_100k_pop'].max(),oceania_df['suicides_100k_pop'].max(),namerica_df['suicides_100k_pop'].max(),samerica_df['suicides_100k_pop'].max()])

# Update axis properties 
fig.update_xaxes(type="log", tickprefix=" ", tickangle=30)
fig.update_yaxes(range=[0,max_suicides],nticks=6)

fig.show()
# Out:
# <div>
#
#
#             <div id="da06b073-6086-481b-b174-2a601f3eb65e" class="plotly-graph-div" style="height:600px; width:900px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("da06b073-6086-481b-b174-2a601f3eb65e")) {
#                     Plotly.newPlot(
#                         'da06b073-6086-481b-b174-2a601f3eb65e',
# ...

# %%
# used for top 10
suicides_per_country = df.groupby(['country'])['suicides_100k_pop'].mean()
suicides_per_country.sort_values(ascending=False, inplace=True)
avg_suicides=suicides_per_country.mean()
switzerland_position=suicides_per_country.reset_index()[suicides_per_country.reset_index()['country']=='Switzerland'].index[0]+1

# used for interesting countries
interesting_countries_array = ['Croatia','Singapore','Italy','Switzerland','France','Germany','Japan', 'United States', 'United Arab Emirates', 'United Kingdom']
interesting_countries = df.loc[df['country'].isin(interesting_countries_array)]
interesting_countries_df = interesting_countries.groupby(['country'])['suicides_100k_pop'].mean()
interesting_countries_df.sort_values(ascending=True, inplace=True)

# used for switzerland vs neighbours
swiss_and_neighbours_array = ['Switzerland','Austria','Italy','Germany','France']
swiss_and_neighbours = df.loc[df['country'].isin(swiss_and_neighbours_array)]
swiss_and_neighbours_df = swiss_and_neighbours.groupby(['country'])['suicides_100k_pop'].mean()
swiss_and_neighbours_df.sort_values(ascending=True, inplace=True)

# %%
fig = make_subplots(
    rows=4,
    cols=1,
    shared_xaxes=True,
    subplot_titles=(
        "Top 10 most impacted countries (per 100k people)",
        "Top 10 least impacted countries (per 100k people)",
        "Other 10 interesting countries (per 100k people)",
        "Switzerland vs Neighbors"
    ),
    vertical_spacing = 0.10,
    #x_title="Suicides (per 100k people)",
)

fig.append_trace(
    go.Bar(
        x=suicides_per_country.values[9::-1],
        y=suicides_per_country.index[9::-1],
        text=suicides_per_country.values[9::-1],
        orientation='h'
    ),
    row=1,
    col=1
)

fig.append_trace(
    go.Bar(
        x=suicides_per_country.values[:-11:-1],
        y=suicides_per_country.index[:-11:-1],
        text=suicides_per_country.values[:-11:-1],
        orientation='h'
    ),
    row=2,
    col=1
)

fig.append_trace(
    go.Bar(
        x=interesting_countries_df.values,
        y=interesting_countries_df.index,
        text=interesting_countries_df.values,
        marker_color='mediumslateblue',
        orientation='h'
    ),
    row=3,
    col=1,
)

fig.append_trace(
    go.Bar(
        x=swiss_and_neighbours_df.values,
        y=swiss_and_neighbours_df.index,
        text=swiss_and_neighbours_df.values,
        marker_color='cadetblue',
        orientation='h'
    ),
    row=4,
    col=1,
)

# Vertical Line (mean of suicides)

fig.add_shape(
        dict(
            type="line",
            x0=avg_suicides,
            y0=-0.5,
            x1=avg_suicides,
            y1=9.5,
            line=dict(
                color="darkblue",
                width=1,
                dash="dot",
            ),
            yref='y1',
            xref="x",
        )
)

fig.add_shape(
        dict(
            type="line",
            x0=avg_suicides,
            y0=-0.5,
            x1=avg_suicides,
            y1=9.5,
            line=dict(
                color="darkblue",
                width=1,
                dash="dot",
            ),
            yref='y2',
            xref="x",
        )
)

fig.add_shape(
        dict(
            type="line",
            x0=avg_suicides,
            y0=-0.5,
            x1=avg_suicides,
            y1=9.5,
            line=dict(
                color="darkblue",
                width=1,
                dash="dot",
            ),
            yref='y3',
            xref="x",
        )
)

fig.add_shape(
        dict(
            type="line",
            x0=avg_suicides,
            y0=-0.5,
            x1=avg_suicides,
            y1=4.5,
            line=dict(
                color="darkblue",
                width=1,
                dash="dot",
            ),
            yref='y4',
            xref="x",
        )
)


          
fig.update_yaxes(title="Country")
fig.update_xaxes(title="Suicides (per 100k people)")
fig.update_layout(
    height=1333, 
    width=900, 
    showlegend=False,
#    annotations=[
#        dict(
#            arrowsize=1,
#            arrowwidth=1,
#            x=avg_suicides,
#            y=2,
#            yref="y3",
#            xref="x",
#            text="avg.",
#            showarrow=True,
#            arrowhead=1,
#            ax=40,
#            ay=40
#        ),
#    ]
)
fig.update_traces(texttemplate='%{text:.2s}', textposition='outside')
fig.update_layout(uniformtext_minsize=8, uniformtext_mode='hide')
fig.show()
print(f'Average suicide rate: {BOLD_BEGIN}{avg_suicides}{BOLD_END}')
print(f'Switzerland position: {BOLD_BEGIN}{switzerland_position}{BOLD_END}')
# Out:
# <div>
#
#
#             <div id="02480a84-7170-4891-9a67-5b5fc51115ab" class="plotly-graph-div" style="height:1333px; width:900px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("02480a84-7170-4891-9a67-5b5fc51115ab")) {
#                     Plotly.newPlot(
#                         '02480a84-7170-4891-9a67-5b5fc51115ab',
# ...

# %%
# %%capture

fig = go.Figure(
    go.Bar(
        x=suicides_per_country.values[9::-1],
        y=suicides_per_country.index[9::-1],
        text=suicides_per_country.values[9::-1],
        orientation='h',
        texttemplate='%{text:.2s}',
        textposition='outside',
    )
)

fig.update_layout(
    title=dict(
        text='Top 10 most impacted countries (per 100k people)',
        y=0.9,
        x=0.5,
        xanchor='center',
        yanchor='top'
    ),
    xaxis=dict(
        title='Suicides (per 100k people)',
        linecolor='rgb(204, 204, 204)',
        tickmode = 'linear',
        tick0 = 0,
        dtick = 5
    ),
    yaxis=dict(
        title='Country',
    ),
    uniformtext_minsize=8,
    uniformtext_mode='hide'
)

fig.show()

# %%
# %%capture

fig = go.Figure(
    go.Bar(
        x=suicides_per_country.values[:-11:-1],
        y=suicides_per_country.index[:-11:-1],
        text=suicides_per_country.values[:-11:-1],
        orientation='h',
        texttemplate='%{text:.2s}',
        textposition='outside',
    )
)

fig.update_layout(
    title=dict(
        text='Top 10 least impacted countries (per 100k people)',
        y=0.9,
        x=0.5,
        xanchor='center',
        yanchor='top'
    ),
    xaxis=dict(
        title='Suicides (per 100k people)',
        linecolor='rgb(204, 204, 204)',
    ),
    yaxis=dict(
        title='Country',
    ),
    uniformtext_minsize=8,
    uniformtext_mode='hide',
)

fig.show()

# %%
world_df = df.groupby(['country','country_code','continent'])['suicides_100k_pop'].mean().reset_index()

# %%
# %%capture

fig = px.scatter_geo(
    world_df,
    locations="country_code",
    color="continent",
    hover_name="country",
    size="suicides_100k_pop",
    projection="natural earth",
)

fig.update_layout(
    title=dict(
        text='Suicides Distribution on Map (per 100k people)',
        y=0.95,
        x=0.5,
        xanchor='center',
        yanchor='top'
    ),
)

fig.show()

# %%
fig = px.choropleth(
    world_df,
    locations="country_code",
    color="suicides_100k_pop",
    hover_name="country",
    labels={'suicides_100k_pop':'Suicides (per 100k ppl)'},
    #color_continuous_scale=["green", "yellow", "orange", "red"])
    color_continuous_scale=px.colors.diverging.Tealrose
)

fig.update_layout(
    title=dict(
        text='Suicides distribution on map (per 100k people)',
        y=0.95,
        x=0.5,
        xanchor='center',
        yanchor='top'
    )
)

fig.show()
# Out:
# <div>
#
#
#             <div id="87024a13-e1b9-4479-a105-b064fb8c4a32" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("87024a13-e1b9-4479-a105-b064fb8c4a32")) {
#                     Plotly.newPlot(
#                         '87024a13-e1b9-4479-a105-b064fb8c4a32',
# ...

# %%
sex_age_df = df.groupby(['age','sex'])['suicides_100k_pop'].mean().reset_index()
sex_age_df.sort_values(ascending=True, inplace=True, by='suicides_100k_pop')
males = sex_age_df.query('sex == "male"')
females = sex_age_df.query('sex == "female"')

sex_year_df = df.groupby(['sex','year'])['suicides_100k_pop'].mean().reset_index()
males_year = sex_year_df.query('sex == "male"')
females_year = sex_year_df.query('sex == "female"')

# %%
fig = go.Figure(
    data=[
        go.Bar(name='Males', x=list(males['age']), y=males['suicides_100k_pop'], text=males['suicides_100k_pop']),
        go.Bar(name='Females', x=list(females['age']), y=females['suicides_100k_pop'], text=females['suicides_100k_pop'])
    ]
)

# Change the bar mode
fig.update_traces(texttemplate='%{text:.2s}', textposition='outside')
fig.update_layout(
    title=dict(
        text='Age Distribution',
        y=0.90,
        x=0.5,
        xanchor='center',
        yanchor='top'
    ),
    xaxis=dict(
        title='Age Range',
        linecolor='rgb(204, 204, 204)',
    ),
    yaxis=dict(
        title='Suicides (per 100k people)',
    ),
    barmode='group',
    uniformtext_minsize=8,
    uniformtext_mode='hide',
)

fig.show()
# Out:
# <div>
#
#
#             <div id="960dc8a3-b7ac-4455-8d49-099773b1cbe6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("960dc8a3-b7ac-4455-8d49-099773b1cbe6")) {
#                     Plotly.newPlot(
#                         '960dc8a3-b7ac-4455-8d49-099773b1cbe6',
# ...

# %%
sex_df=df.groupby(['sex'])['suicides_100k_pop'].mean().reset_index()

# %%
# %%capture

fig = px.pie(sex_df, values='suicides_100k_pop', names='sex', hover_data=['suicides_100k_pop'])
fig.update_layout(
    title=dict(
        text='Gender Distribution',
        y=0.95,
        x=0.5,
        xanchor='center',
        yanchor='top'
    )
)
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.show()

# %%
fig = make_subplots(
    rows=2,
    cols=2,
    horizontal_spacing = 0.2,
    specs=[[{"type": "domain","rowspan": 2}, {}],[{}, {}]],
    column_widths=[0.39, 0.61],
    shared_xaxes=True,
)    

fig.add_trace(
    go.Pie(
        values=sex_df['suicides_100k_pop'],
        labels=sex_df['sex'],
        textinfo='label+percent',
        hole=.3
    ),
    row=1,
    col=1
)

fig.add_trace(
    go.Scatter(
        name="Males",
        x=males_year['year'],
        y=males_year['suicides_100k_pop'],
        line=dict(color='blue'),
        showlegend=False
    ),
    row=1,
    col=2
)


fig.add_trace(
    go.Scatter(
        name="Females",
        x=females_year['year'],
        y=females_year['suicides_100k_pop'],
        line=dict(color='rgb(241, 105, 19)'),
        showlegend=False
    ),
    row=2,
    col=2
)


fig.update_layout(height=500, width=900,
    title=dict(
        text='Gender Distribution and Trend (per 100k people)',
        y=0.90,
        x=0.5,
        xanchor='center',
        yanchor='top'
    ),
)

max_suicides = 5 + max([males_year['suicides_100k_pop'].max(), females_year['suicides_100k_pop'].max()])
#fig.update_yaxes(range=[0,max_suicides], nticks=6, row=1, col=2)
#fig.update_yaxes(range=[0,max_suicides], nticks=6, row=2, col=2)
fig.update_yaxes(title="Suicides (100k ppl)", col=2)
fig.update_xaxes(title="Year", row=2, col=2, type="log", tickangle=30)
fig.update_xaxes(row=1, col=2, type="log")
fig.show()
# Out:
# <div>
#
#
#             <div id="8ff46e9f-45a5-4e40-9315-3e97e8b800ab" class="plotly-graph-div" style="height:500px; width:900px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8ff46e9f-45a5-4e40-9315-3e97e8b800ab")) {
#                     Plotly.newPlot(
#                         '8ff46e9f-45a5-4e40-9315-3e97e8b800ab',
# ...

# %%
fig = make_subplots(
    rows=2,
    cols=2,
    horizontal_spacing = 0.2,
    specs=[[{"type": "domain","rowspan": 2}, {}],[{}, {}]],
    column_widths=[0.39, 0.61],
    shared_xaxes=True,
)    

fig.add_trace(
    go.Pie(
        values=sex_df['suicides_100k_pop'],
        labels=sex_df['sex'],
        textinfo='label+percent',
        hole=.3
    ),
    row=1,
    col=1
)

fig.add_trace(
    go.Scatter(
        name="Males",
        x=males_year['year'],
        y=males_year['suicides_100k_pop'],
        line=dict(color='blue'),
        showlegend=False
    ),
    row=1,
    col=2
)


fig.add_trace(
    go.Scatter(
        name="Females",
        x=females_year['year'],
        y=females_year['suicides_100k_pop'],
        line=dict(color='rgb(241, 105, 19)'),
        showlegend=False
    ),
    row=2,
    col=2
)


fig.update_layout(height=500, width=900,
    title=dict(
        text='Gender Distribution and Trend (per 100k people)',
        y=0.90,
        x=0.5,
        xanchor='center',
        yanchor='top'
    ),
)

max_suicides = 5 + max([males_year['suicides_100k_pop'].max(), females_year['suicides_100k_pop'].max()])
fig.update_yaxes(range=[0,max_suicides], nticks=6, row=1, col=2)
fig.update_yaxes(range=[0,max_suicides], nticks=6, row=2, col=2)
fig.update_yaxes(title="Suicides (100k ppl)", col=2)
fig.update_xaxes(title="Year", row=2, col=2, type="log", tickangle=30)
fig.update_xaxes(row=1, col=2, type="log")
fig.show()
# Out:
# <div>
#
#
#             <div id="b714b546-b706-4f12-8a0a-5b67929c8b0a" class="plotly-graph-div" style="height:500px; width:900px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b714b546-b706-4f12-8a0a-5b67929c8b0a")) {
#                     Plotly.newPlot(
#                         'b714b546-b706-4f12-8a0a-5b67929c8b0a',
# ...

# %%
generations_suicides=df.groupby(['generation'])[['suicides_100k_pop']].mean().reset_index()
generations_suicides_year=df.groupby(['generation','year'])[['suicides_100k_pop']].mean().reset_index()
generations_suicides_year.sort_values(ascending=True, inplace=True, by='year')

# %%
fig = make_subplots(
    rows=1,
    cols=2,
    horizontal_spacing = 0.2,
    column_widths=[0.39, 0.61],
    specs=[[{"type": "domain"}, {}]]
)    

fig.add_trace(go.Pie(
    values=generations_suicides['suicides_100k_pop'],
    labels=generations_suicides['generation'],
    textinfo='percent',
    showlegend=True,
    hole=.3
),row=1, col=1)


fig2 = px.line(generations_suicides_year, x="year", y="suicides_100k_pop", color='generation')
fig2['data'][0].showlegend = False
fig2['data'][1].showlegend = False
fig2['data'][2].showlegend = False
fig2['data'][3].showlegend = False
fig2['data'][4].showlegend = False
fig2['data'][5].showlegend = False


fig.append_trace(fig2['data'][0], row=1, col=2)
fig.append_trace(fig2['data'][1], row=1, col=2)
fig.append_trace(fig2['data'][2], row=1, col=2)
fig.append_trace(fig2['data'][3], row=1, col=2)
fig.append_trace(fig2['data'][4], row=1, col=2)
fig.append_trace(fig2['data'][5], row=1, col=2)

fig.update_yaxes(title="Suicides (100k ppl)", row=1, col=2)
fig.update_xaxes(title="Year", col=2, type="log")

fig.update_layout(
    title=dict(
        text='Generation Distribution and Trend (per 100k people)',
        y=0.90,
        x=0.5,
        xanchor='center',
        yanchor='top'
    )
)

fig.show()
# Out:
# <div>
#
#
#             <div id="781e3c32-8343-4e69-bb9c-580997bb6fb9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("781e3c32-8343-4e69-bb9c-580997bb6fb9")) {
#                     Plotly.newPlot(
#                         '781e3c32-8343-4e69-bb9c-580997bb6fb9',
# ...

# %%
# %%capture

fig = px.pie(generations_suicides, values='suicides_100k_pop', names='generation')
fig.update_layout(
    title=dict(
        text='Suicides percentage per generation',
        y=0.95,
        x=0.5,
        xanchor='center',
        yanchor='top'
    )
)

fig.show()

# %%
age_year_df=df.groupby(['age','year'])['suicides_100k_pop'].mean().reset_index()
age_year_df.sort_values(['year', 'suicides_100k_pop'], ascending=[True, True], inplace=True)

# %%
fig = px.line(
    age_year_df,
    x="year",
    y="suicides_100k_pop",
    color='age',
    labels={'age':'Age'},
)

fig.update_layout(
    title=dict(
        text='Suicides trend per age overtime',
        y=0.95,
        x=0.5,
        xanchor='center',
        yanchor='top'
    )
)

fig.update_yaxes(title="Suicides (100k people)")
fig.update_xaxes(title="Year")

fig.show()
# Out:
# <div>
#
#
#             <div id="d06ce8bd-dad6-45a9-b559-6f03e378d98c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d06ce8bd-dad6-45a9-b559-6f03e378d98c")) {
#                     Plotly.newPlot(
#                         'd06ce8bd-dad6-45a9-b559-6f03e378d98c',
# ...

# %%
f,ax = plt.subplots(figsize=(12, 6))
sns.heatmap(df.corr(), annot=True, linewidths=0.5,cmap='YlGnBu', fmt= '.1f',ax=ax)
plt.title('Correlation Matrix', y=21.3, fontsize = 20)
plt.margins(x=0, y=0) 
plt.show()

# %%
correlation_scatter1 = df.groupby(['country','continent'])[['gdp_per_capita', 'gdp_for_year','suicides_100k_pop','population']].mean().reset_index()
hdi_not_null_df = df[df['hdi_for_year'].notnull()]
correlation_scatter2 = hdi_not_null_df.groupby(['country','continent'])[['hdi_for_year', 'suicides_100k_pop']].mean().reset_index()

corrcoef_suicides_gdpyear=np.corrcoef(scatter1['suicides_100k_pop'],scatter1['gdp_for_year'])[0,1]
corrcoef_suicides_gdpcapita=np.corrcoef(scatter1['suicides_100k_pop'],scatter1['gdp_per_capita'])[0,1]
corrcoef_suicides_population=np.corrcoef(scatter1['suicides_100k_pop'],scatter1['population'])[0,1]
corrcoef_suicides_hdi=np.corrcoef(scatter2['suicides_100k_pop'],scatter2['hdi_for_year'])[0,1]

# %%
# fig = px.scatter(scatter, x="gdp_per_capita", y="suicides_100k_pop", trendline='ols')
# fig = px.scatter(scatter, x="gdp_for_year", y="suicides_100k_pop", trendline='ols')
# fig = px.scatter(scatter, x="population", y="suicides_100k_pop", trendline='ols')
# fig = px.scatter(scatter2, x="hdi_for_year", y="suicides_100k_pop", color='continent',trendline='ols')
# fig = px.scatter(scatter2, x="hdi_for_year", y="suicides_100k_pop",trendline='ols')

fig = make_subplots(
    rows=2,
    cols=2,
    #subplot_titles=("gdp_for_year", "gdp_per_capita", "population", "hdi_for_year"),
    shared_yaxes=True,
    y_title="Suicides (per 100k people)",
    vertical_spacing = 0.20,
)

fig1 = px.scatter(correlation_scatter1, x="gdp_for_year", y="suicides_100k_pop", hover_name='country', trendline='ols')
fig2 = px.scatter(correlation_scatter1, x="gdp_per_capita", y="suicides_100k_pop", hover_name='country', trendline='ols')
fig3 = px.scatter(correlation_scatter1, x="population", y="suicides_100k_pop", hover_name='country', trendline='ols')
fig4 = px.scatter(correlation_scatter2, x="hdi_for_year", y="suicides_100k_pop", hover_name='country', trendline='ols')

fig.append_trace(fig1['data'][0], row=1, col=1)
fig.append_trace(fig1['data'][1], row=1, col=1)

fig.append_trace(fig2['data'][0], row=1, col=2)
fig.append_trace(fig2['data'][1], row=1, col=2)

fig.append_trace(fig3['data'][0], row=2, col=1)
fig.append_trace(fig3['data'][1], row=2, col=1)

fig.append_trace(fig4['data'][0], row=2, col=2)
fig.append_trace(fig4['data'][1], row=2, col=2)

fig.update_layout(
    height=500,
    width=900,
    showlegend=False,
    title=dict(
        text='Suicides (per 100k people) correlations',
        y=0.90,
        x=0.5,
        xanchor='center',
        yanchor='top'
    ),
)

fig.update_xaxes(title='GDP for year',row=1, col=1)
fig.update_xaxes(title='GDP per capita',row=1, col=2)
fig.update_xaxes(title='Population',row=2, col=1)
fig.update_xaxes(title='HDI',row=2, col=2)

fig.show()

print(f'Correlation suicides and gdp for year: {BOLD_BEGIN}{corrcoef_suicides_gdpyear}{BOLD_END}')
print(f'Correlation suicides and gdp pro capita: {BOLD_BEGIN}{corrcoef_suicides_gdpcapita}{BOLD_END}')
print(f'Correlation suicides and population: {BOLD_BEGIN}{corrcoef_suicides_population}{BOLD_END}')
print(f'Correlation suicides and hdi: {BOLD_BEGIN}{corrcoef_suicides_hdi}{BOLD_END}')
# Out:
# <div>
#
#
#             <div id="e1c95278-5065-49f0-8f60-20411adcb332" class="plotly-graph-div" style="height:500px; width:900px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e1c95278-5065-49f0-8f60-20411adcb332")) {
#                     Plotly.newPlot(
#                         'e1c95278-5065-49f0-8f60-20411adcb332',
# ...

# %% [markdown]
# ## Correlation Coefficient

# %%
only_2004 = df[df['year'] == 2004].copy()
for country in only_2004['country'].unique():
    if df3[df3['Country'] == country]['Country'].any():
        uv_radiation_for_country = df3[df3['Country'] == country]['UV radiation'].iloc[0]
        only_2004.loc[only_2004['country'] == country, 'UV radiation'] = uv_radiation_for_country

only_2004_uv_not_null = only_2004.loc[only_2004['UV radiation'].notnull()].copy()
uv_suicides_corr_df = only_2004_uv_not_null.groupby(['country','continent','UV radiation'])[['suicides_100k_pop']].mean().reset_index()
corrcoef_suicides_uv=np.corrcoef(scatter3['suicides_100k_pop'],scatter3['UV radiation'])[0,1]

# %%
fig = px.scatter(uv_suicides_corr_df, x="UV radiation", y='suicides_100k_pop', hover_name='country', trendline='ols')

fig.update_layout(
    title=dict(
        text='Correletion between UV Radiation and Suicides globally in year 2004',
        y=0.95,
        x=0.5,
        xanchor='center',
        yanchor='top'
    ),
)

fig.update_yaxes(title="Suicides (100k people)")
fig.update_xaxes(title="UV Radiation")
fig.add_annotation(ax=20, ay=-40, x=10224, y=0.31166, text="Maldives<br><b>Suicide rate: ~0.3</b>")
fig.add_annotation(ax=-0, ay=-40, x=5203, y=33.333, text="Guyana<br><b>Suicide rate: ~33.3</b>")
fig.add_annotation(ax=20, ay=70, x=957, y=14.0675, text="Iceland<br><b>Suicide rate: ~14.1</b>")
fig.add_annotation(ax=-20, ay=-40, x=1801, y=41.9475, text="Lithuania<br><b>Suicide rate: ~41.9</b>")
fig.add_annotation(ax=60, ay=-40, x=2257, y=34.488, text="Kazakhistan<br><b>Suicide rate: ~34.5</b>")

fig.show()

print(f'Correlation suicides and uv radiation in 2004: {BOLD_BEGIN}{corrcoef_suicides_uv}{BOLD_END}')
# Out:
# <div>
#
#
#             <div id="f7f14a77-dca4-4bff-a568-a45cfcf381bc" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f7f14a77-dca4-4bff-a568-a45cfcf381bc")) {
#                     Plotly.newPlot(
#                         'f7f14a77-dca4-4bff-a568-a45cfcf381bc',
# ...

# %%
country_suicide_dict = df.groupby(['country'])[['suicides_100k_pop']].mean().to_dict()['suicides_100k_pop']

# %%
f,ax = plt.subplots(figsize=(16, 9))

wordcloud = WordCloud(
    background_color ='white',
    height=900,
    width=1000
).generate_from_frequencies(country_suicide_dict)

plt.title('Suicides per country', y=1.05, fontsize = 20)

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0) 
plt.show()

# %%
year_age_df = df.groupby(['year','age'])[['suicides_100k_pop']].mean().reset_index()
year_age_df.sort_values(ascending=True, inplace=True, by='suicides_100k_pop')

# %%
fig = px.box(
    year_age_df,
    x="age",
    y="suicides_100k_pop"
)

fig.update_traces(quartilemethod="linear", boxpoints='suspectedoutliers')

fig.update_xaxes(title='Year')

fig.update_yaxes(title='Suicides (per 100k population)')

fig.update_layout(
    title=dict(
        text='Global Age Comparison',
        y=0.95,
        x=0.5,
        xanchor='center',
        yanchor='top'
    ),
)

fig.show()
# Out:
# <div>
#
#
#             <div id="6f759f5b-0b9b-4690-9384-1bfa1557a6d8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6f759f5b-0b9b-4690-9384-1bfa1557a6d8")) {
#                     Plotly.newPlot(
#                         '6f759f5b-0b9b-4690-9384-1bfa1557a6d8',
# ...

# %%
year_country_df = df.groupby(['year','country'])[['suicides_100k_pop']].mean().reset_index()

# %%
fig = px.box(year_country_df, x="year", y="suicides_100k_pop", hover_name="country")
fig.update_traces(quartilemethod="linear", boxpoints='outliers')
fig.update_xaxes(title='Year', type='category', tickangle=45)
fig.update_yaxes(title='Suicides (per 100k population)')
# Out:
# <div>
#
#
#             <div id="b5d066f2-9c46-45da-9892-6a78a2ba451a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b5d066f2-9c46-45da-9892-6a78a2ba451a")) {
#                     Plotly.newPlot(
#                         'b5d066f2-9c46-45da-9892-6a78a2ba451a',
# ...

# %%
world_df = df.groupby(['country','country_code','continent','population'])['suicides_100k_pop'].mean().reset_index()
world_df["world"] = "World" # in order to have a single root node

# %%
fig = px.treemap(
    world_df,
    path=['world', 'continent', 'country_code'],
    color='suicides_100k_pop',
    values='population',
    hover_data=['country'],
    color_continuous_scale=px.colors.diverging.Tealrose,
    labels={'suicides_100k_pop':'Suicides (per 100k ppl)'}
)
fig.show()
# Out:
# <div>
#
#
#             <div id="2a503067-f658-47dc-8705-62230eb3ef3b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2a503067-f658-47dc-8705-62230eb3ef3b")) {
#                     Plotly.newPlot(
#                         '2a503067-f658-47dc-8705-62230eb3ef3b',
# ...
